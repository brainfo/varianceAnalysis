# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.chdir('/mnt/data/hong/courses/varianceAnalysis/')

# %%
cosmos = pd.read_csv('data/Gene_mutationsMon Feb  5 22_45_37 2024.tsv', sep='\t')

# %%
sum(cosmos['Type'].str.contains('Substitution'))
# Out:
# 155

# %%
tissue = pd.read_csv('data/Gene_samplesMon Feb  5 22_52_52 2024.tsv', sep='\t')

# %%
fig, ax = plt.subplots()
tissue['Primary Tissue'].value_counts().plot(ax=ax, kind='bar')
plt.savefig('figures/cosmos_tissue.png')
